# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis, mode
from tabulate import tabulate

# %%
df = pd.read_csv("C:/Users/Administrator/Documents/heart_disease_uci.csv")

# %%
display(df.head())
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
display(df.tail())
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak slope  ca          thal  num
# 915  st-t abnormality   154.0  False      0.0   NaN NaN           NaN    1
# 916  st-t abnormality     NaN    NaN      NaN   NaN NaN           NaN    0
# 917  st-t abnormality   100.0  False      0.0   NaN NaN  fixed defect    2
# 918    lv hypertrophy     NaN    NaN      NaN   NaN NaN           NaN    0
# 919    lv hypertrophy    93.0   True      0.0   NaN NaN           NaN    1

# %%
display(df.isnull())
# Out:
#         id    age    sex  dataset     cp  trestbps   chol    fbs  restecg  \
# 0    False  False  False    False  False     False  False  False    False
# 1    False  False  False    False  False     False  False  False    False
# 2    False  False  False    False  False     False  False  False    False
# 3    False  False  False    False  False     False  False  False    False
# 4    False  False  False    False  False     False  False  False    False
# ..     ...    ...    ...      ...    ...       ...    ...    ...      ...
# 915  False  False  False    False  False     False  False  False    False
# 916  False  False  False    False  False      True  False  False    False
# 917  False  False  False    False  False     False  False  False    False
# 918  False  False  False    False  False      True  False  False    False
# 919  False  False  False    False  False     False  False  False    False
#
#      thalch  exang  oldpeak  slope     ca   thal    num
# ...

# %%
display(df.isnull)
# Out:
# <bound method DataFrame.isnull of       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
# !pip install scipy

# %%
numeric_df = df.select_dtypes(include=[np.number])

def calculate_statistics(df):
    stats = pd.DataFrame(index=df.columns, columns=['Mean', 'Median', 'Mode', 'Std Dev', 'Variance', 'Skewness', 'Kurtosis'])

    
    
numeric_cols = df.select_dtypes(include=[np.number]).columns
for col in numeric_cols:
    print(f"\nStatistik untuk {col} : ")
    print(f"Mean               : {df[col].mean()}")
    print(f"Median             : {df[col].median()}")
    print(f"Mode               : {df[col].mode()[0]}")
    print(f"Standar Deviasi    : {df[col].std()}")
    print(f"Variansi           : {df[col].var()}")
    print(f"Skewness           : {df[col].skew()}")
    print(f"Kurtosis           : {df[col].kurt()}")




# Menghitung dan menampilkan statistik
statistics = calculate_statistics(df)
print(statistics)

correlation_matrix = numeric_df.corr()
print("\nMatriks Korelasi:\n", correlation_matrix)

# Plot heatmap korelasi
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True, square=True, fmt='.2f')
plt.title('Heatmap Korelasi Antar Variabel')
plt.show()
# Out:
# Statistik untuk id :
# Mean               : 460.5
# Median             : 460.5
# Mode               : 1
# Standar Deviasi    : 265.72542219366215
# Variansi           : 70610.0
# Skewness           : 0.0
# Kurtosis           : -1.2
#
# Statistik untuk age :
# Mean               : 53.51086956521739
# Median             : 54.0
# Mode               : 54
# Standar Deviasi    : 9.424685209576857
# Variansi           : 88.82469129961677
# Skewness           : -0.195993861608106
# Kurtosis           : -0.3829298182845311
#
# Statistik untuk trestbps :
# Mean               : 132.13240418118468
# Median             : 130.0
# Mode               : 120.0
# Standar Deviasi    : 19.066069518587458
# Variansi           : 363.51500688760973
# Skewness           : 0.21333446967212508
# Kurtosis           : 2.958664416580538
#
# Statistik untuk chol :
# Mean               : 199.13033707865168
# Median             : 223.0
# Mode               : 0.0
# Standar Deviasi    : 110.78081035323044
# ...

# %%
for col in numeric_df.columns:
    plt.figure(figsize=(14, 5))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(numeric_df[col], kde=True, bins=10, color='skyblue')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

    # Box Plot
    plt.subplot(1, 2, 2)
    sns.boxplot(x=numeric_df[col], color='lightcoral')
    plt.title(f'Box Plot of {col}')
    plt.xlabel(col)

    plt.tight_layout()
    plt.show()

# %%
sns.pairplot(df, hue ='age', palette='Reds')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# !pip install tabulate

# %%
print('Berdasarkan analisis awal terhadap data dari file yang Anda berikan, berikut adalah ringkasan temuan:')
print('1. Struktur Data')
print('Data terdiri dari kolom-kolom yang memberikan informasi mengenai pasien seperti usia, jenis kelamin, tekanan darah, kolesterol, dan lain-lain, termasuk hasil diagnosis. Terdapat berbagai tipe data, baik numerik maupun kategorikal.')
print('')
print('2. Nilai yang Hilang')
print('Beberapa kolom menunjukkan jumlah nilai hilang yang signifikan:')
print('- Tekanan darah (trestbps): 59 nilai hilang.')
print('- Kolesterol (chol): 30 nilai hilang.')
print('- Detak jantung maksimum (thalch): 55 nilai hilang.')
print('- Depresi ST (oldpeak): 62 nilai hilang.')
print('- Kolom slope, ca, dan thal juga memiliki nilai hilang yang tinggi, terutama ca (611 nilai hilang) dan thal (486 nilai hilang).')
print('')
print('3. Distribusi yang Tidak Normal')
print('- Variabel numerik seperti usia, tekanan darah, dan kolesterol mungkin memiliki distribusi yang tidak normal, terutama jika terdapat skewness tinggi atau outliers.')
print('- Diperlukan analisis lebih mendalam seperti histogram dan box plot untuk memastikan apakah distribusi tidak normal benar adanya.')
print('')
print('4. Korelasi Antar Variabel')
print('- Heatmap korelasi menunjukkan adanya beberapa variabel dengan hubungan yang kuat, tetapi variabel spesifik yang berkorelasi belum diidentifikasi secara rinci.')
print('- Scatter plot untuk pasangan variabel dengan korelasi tinggi harus diperiksa untuk memastikan adanya hubungan linier yang signifikan.')
print('')
print('5. Outliers')
print('- Berdasarkan statistik awal, kemungkinan terdapat outliers pada kolom kolesterol dan tekanan darah, yang bisa menyebabkan deviasi tinggi.')
print('- Box plot akan membantu dalam mengidentifikasi outliers yang signifikan dalam data.')
print('')
print('6. Temuan Utama')
print('- Distribusi: Ada indikasi bahwa distribusi variabel numerik mungkin tidak normal dan menunjukkan skewness, sehingga uji normalitas mungkin diperlukan.')
print('- Korelasi Kuat: Beberapa pasangan variabel menunjukkan korelasi yang kuat, yang penting untuk dipertimbangkan dalam analisis regresi atau model prediksi.')
print('- Nilai yang Hilang: Beberapa kolom dengan jumlah nilai hilang yang tinggi perlu diproses lebih lanjut menggunakan metode imputasi atau lainnya untuk menjaga kualitas data.')
print('')
print('')
print('')
print('')
print('')
print('')
print('')
print('')
print('')
print('')
print('')
print('')
print('')
# Out:
# Berdasarkan analisis awal terhadap data dari file yang Anda berikan, berikut adalah ringkasan temuan:
# 1. Struktur Data
# Data terdiri dari kolom-kolom yang memberikan informasi mengenai pasien seperti usia, jenis kelamin, tekanan darah, kolesterol, dan lain-lain, termasuk hasil diagnosis. Terdapat berbagai tipe data, baik numerik maupun kategorikal.
#
# 2. Nilai yang Hilang
# Beberapa kolom menunjukkan jumlah nilai hilang yang signifikan:
# - Tekanan darah (trestbps): 59 nilai hilang.
# - Kolesterol (chol): 30 nilai hilang.
# - Detak jantung maksimum (thalch): 55 nilai hilang.
# - Depresi ST (oldpeak): 62 nilai hilang.
# - Kolom slope, ca, dan thal juga memiliki nilai hilang yang tinggi, terutama ca (611 nilai hilang) dan thal (486 nilai hilang).
#
# 3. Distribusi yang Tidak Normal
# - Variabel numerik seperti usia, tekanan darah, dan kolesterol mungkin memiliki distribusi yang tidak normal, terutama jika terdapat skewness tinggi atau outliers.
# ...
